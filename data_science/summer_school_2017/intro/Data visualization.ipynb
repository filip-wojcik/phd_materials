# %% [markdown]
# # Data visualization excercises

# %% [markdown]
# In this section you'll learn how to visualize data in Pandas and sklearn.
#
# As before - you'll be asked to fill missing '??' in the code with proper answers.
#
# Some excercises will require aggregating data, grouping and transforming - so knowledge from previous modules is highly appreciated
#
# Expected results will be shown below each excersise. No assertions this time :) You just need to get similar results as shown

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.datasets as ds

# %%
# %matplotlib inline

# %%
plt.style.use('ggplot')

# %% [markdown]
# ## Excercise 1

# %%
# Excercise 1 data

df1 = pd.DataFrame({
    'value': list(range(0, 10)) + list(range(5, 15)),
    'category': ['a'] * 10 + ['b'] * 10    
})

# %%
# Excercise 1a: try to obtain similar plot using PANDAS, as presented below:
# Can you describe what the plot means?

# %%
# YOU CODE GOES HERE!

# %%
# Excercise 1b: try to obtain similar plot using PANDAS, as presented below
# Can you describe what the plot means?

# %%
# YOU CODE GOES HERE!

# %%
# Excercise 1c: try to obtain similar plot using PANDAS, as presented below
# Can you describe what the plot means?

# %%
# YOU CODE GOES HERE!

# %% [markdown]
# ## Excercise 2

# %% [markdown]
# Info about the dataset:
#
# https://www.kaggle.com/c/titanic/data
#
# Data Dictionary
#
# | Variable | Definition                                 | Key                                            |
# |----------|--------------------------------------------|------------------------------------------------|
# | survival | Survival                                   | 0 = No, 1 = Yes                                |
# | pclass   | Ticket class                               | 1 = 1st, 2 = 2nd, 3 = 3rd                      |
# | sex      | Sex                                        |                                                |
# | Age      | Age in years                               |                                                |
# | sibsp    | # of siblings / spouses aboard the Titanic |                                                |
# | parch    | # of parents / children aboard the Titanic |                                                |
# | ticket   | Ticket number                              |                                                |
# | fare     | Passenger fare                             |                                                |
# | cabin    | Cabin number                               |                                                |
# | embarked | Port of Embarkation                        | C = Cherbourg, Q = Queenstown, S = Southampton |
#
#
# pclass: A proxy for socio-economic status (SES)
#
#     1st = Upper
#     2nd = Middle
#     3rd = Lower
#
# age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# sibsp: The dataset defines family relations in this way...
# Sibling = brother, sister, stepbrother, stepsister
# Spouse = husband, wife (mistresses and fiancés were ignored)
#
# parch: The dataset defines family relations in this way...
# Parent = mother, father
# Child = daughter, son, stepdaughter, stepson
# Some children travelled only with a nanny, therefore parch=0 for them.

# %%
titanic_data = pd.DataFrame.from_csv("./data/titanic_train_data.csv", index_col=None)

# %%
titanic_data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Excercise 2a: compare age distribution of all male and females on Titanic?
# can you desscribe what the plot below means?

# %%
# YOU CODE GOES HERE!

# %%
"""
Excercise 2b: plot proportion of males who survived vs females who survived
"""

# %%
# YOU CODE GOES HERE!

# %%
"""
Excercise 2c: Plot the proportion of passenger class inside each gender
"""

# %%
# YOU CODE GOES HERE!

# %%
"""
Excercise 2d: Compare number of passengers who survived in each sub-group: by gender and passenger class.
What is this chart saying about survivability of Titanic passengers? Which group was "the most lucky"?
"""

# %%
# YOU CODE GOES HERE!

# %% [markdown]
# Excercise 2e: Use your skills aquired during Data manipulation module to transform data, to extract **people who had a family** and create a new column for that.
#
# Use the following definition of **with_family** = Parch + SibSp
#
# Interpretation is: person had family if she/he was travelling with parent(s)/child(ren) and/or sibling(s)/spouse.
#
# Then:
#     1. plot number of survivors in each group - as a barchart and piechart of proportions
#     2. plot number of males/females in each category

# %%
# YOU CODE GOES HERE!

# %%
"""
Excercise 2e: Compare fares between:
    a. Males/Females
    b. Passenger classes
    c. Having/non having family
    
Resize plots if neccessary to make them more redealble
"""

# %%
# YOU CODE GOES HERE!
